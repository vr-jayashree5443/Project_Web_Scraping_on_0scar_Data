# %% [markdown]
# # PART 1

# %% [markdown]
# Web Scraping
# Library - BeautifulSoup(Beginner)
#           Scrapy(Advanced)
#
# https://pypi.org/project/beautifulsoup4/

# %% [markdown]
# 1. Import Libraries

# %%
# !pip install beautifulsoup4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# 2. Web Scrapping

# %%
# Try Website  -1
url = "https://www.amazon.in/s?k=laptop&crid=30M2928CTDH9D&sprefix=laptop%2Caps%2C266&ref=nb_sb_noss_1"
req =requests.get(url)

# %%
req
# Out:
# <Response [500]>

# %%
#<Response [503]> -- denied to give data

# %%
# Try Website  -2
url ="https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
req =requests.get(url)

# %%
req
# Out:
# <Response [500]>

# %%
#<Response [500]> -- the server encountered an unexpected condition
                      # that prevented it from fulfilling the request

# %%
soup = BeautifulSoup(req.content)

# %%
soup
# Out:
# <html><body><h1>500 Internal Server Error</h1>
# An internal server error occurred.
# </body></html>

# %%
# Try Website  - 3
url="https://www.jiomart.com/search/laptop"
req =requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
####################################################################################################

# %%
url="https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"
req= requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Academy Award–winning films - Wikipedia</title>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   List of Academy Award–winning films - Wikipedia\n  </title>\n  <script>\n   (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1
# ...

# %%
for i in soup:
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Up_(1984_film)" title="Up (1984 film)">Up</a></i></td>
# <td><a href="/wiki/1984_in_film" title="1984 in film">1984</a></td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr>
# <td><i><span data-sort-value="Woman in Red, The"><span class="vcard"><span class="fn"><a href="/wiki/The_Woman_in_Red_(1984_film)" title="The Woman in Red (1984 film)">The Woman in Red</a></span></span></span></i></td>
# <td><a href="/wiki/1984_in_film" title="1984 in film">1984</a></td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr>
# <td><i><span data-sort-value="River, The"><span class="vcard"><span class="fn"><a href="/wiki/The_River_(1984_film)" title="The River (1984 film)">The River</a></span></span></span></i></td>
# <td><a href="/wiki/1984_in_film" title="1984 in film">1984</a></td>
# <td>0 (1)</td>
# <td>4
# </td></tr>
# <tr style="background:#EEDD82">
# ...

# %%
#see that website, there is  table, we need to recreate it here afer scraping

# %% [markdown]
# pattern: <tr> tag

# %%
arr=[]
for i in soup.findAll('tr'):
  arr.append(i)

# %%
arr[0]
# Out:
# <tr>
# <th>Film
# </th>
# <th>Year
# </th>
# <th data-sort-type="number">Awards
# </th>
# <th data-sort-type="number">Nominations
# </th></tr>

# %%
arr=[]
for i in soup.findAll('td'):
  arr.append(i)

# %%
arr[0]
# Out:
# <td><i><b><a href="/wiki/Oppenheimer_(film)" title="Oppenheimer (film)">Oppenheimer</a></b></i></td>

# %%
arr[3]
# Out:
# <td>13
# </td>

# %%
arr[4]# next row data
#every 5th element--> new row
# Out:
# <td><i><a href="/wiki/Poor_Things_(film)" title="Poor Things (film)">Poor Things</a></i></td>

# %% [markdown]
# arr[0]
#
# arr[1]
#
# arr[2]
#
# arr[3]
#
# then repeats
#
# therefor for each write re - to clean

# %%
# Sample1--say-- arr[0]#########################################################################
#take arr[0]
# clean

# %%
#Step-1--cutting before
re.sub('^<td>.*">',"",str(arr[0]))
#(">) is till which should replace
# eg: ings (film)">
# Out:
# 'Oppenheimer</a></b></i></td>'

# %%
#Step-2--cutting before and after
re.sub('^<td>.*">|</.*</td>$',"",str(arr[0]))
#(">) is till which should replace
# eg: ings (film)">
# Out:
# 'Oppenheimer'

# %%
#take arr[4]
# clean

# %%
#Step-1--use the same, try if its suitable
re.sub('^<td>.*">|</.*</td>$',"",str(arr[4]))
#(">) is till which should replace
# eg: ings (film)">
# Out:
# 'Poor Things'

# %%
#take arr[8]
# clean

# %%
#Step-1--use the same, try if its suitable
re.sub('^<td>.*">|</.*</td>$',"",str(arr[8]))
#(">) is till which should replace
# eg: ings (film)">
# Out:
# 'The Zone of Interest'

# %%
#arr[0]-- done, suits for arr[4], arr[8], etc

# %%
# Sample2--say-- arr[1]#########################################################################
#take arr[1]
# clean

# %%
arr[1]
# Out:
# <td><a href="/wiki/2023_in_film" title="2023 in film">2023</a></td>

# %%
#saw in webpage
# few lines-- its'2023'
# in few lines the format is'	2020/21'

# %%
re.sub('^<td>.*">|</.*</td>$',"",str(arr[1])) # same works out
# Out:
# '2023'

# %%
#take arr[5]
# clean
re.sub('^<td>.*">|</.*</td>$',"",str(arr[5])) # same works out
# Out:
# '2023'

# %%
#take arr[41]
# clean
re.sub('^<td>.*">|</.*</td>$',"",str(arr[9])) # same works out
# Out:
# '2023'

# %%
# Sample3--say-- arr[2]#########################################################################
#take arr[1]
# clean

# %%
arr[2]
# Out:
# <td>7</td>

# %%
#take arr[2]
# clean
re.sub('<td>|</td>',"",str(arr[2])) # same works out
# Out:
# '7'

# %%
#keep the previous re and do
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[2])) # same, along with new part, it works out
# Out:
# '7'

# %%
#take arr[5]
# clean
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[6])) # same, along with new part, it works out
# Out:
# '4'

# %%
########################till now- what pattern got, try for all#########################
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[0]))# works
# Out:
# 'Oppenheimer'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[1]))# works
# Out:
# '2023'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[2]))# works
# Out:
# '7'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>',"",str(arr[3]))# not working
# Out:
# '13\n'

# %%
#improvise for this
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[3]))# works
# Out:
# '13'

# %%
#######################till now- what pattern got(after improvised), try for all#########################

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[0]))# works
# Out:
# 'Oppenheimer'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[1]))# works
# Out:
# '2023'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[2]))# works
# Out:
# '7'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[3]))# works
# Out:
# '13'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[4]))# works
# Out:
# 'Poor Things'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[5]))# works
# Out:
# '2023'

# %%
re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[6]))# works
# Out:
# '4'

# %%
############################################################################################

# %%
# Now we know arr[0], arr[1], arr[2], arr[3] one row,  each one is element in column
# refer website
# The columns are: Film, Year, Award, Nomination
# Accordingly.............................................................

# %%
Film=[] #arr[0], arr[4], arr[8], should come here.................
Year=[] # arr[1], arr[5], arr[9], should come here.................
Award =[] #arr[2], arr[6], arr[10], should come here.................
Nomination=[] # arr[3], arr[7], arr[11], should come here.................
# for i in soup.findAll('td'):
#   arr.append(i)
a=soup.findAll('td')
# for i in range(len(a)-4):
#   Film.append(a[i])
#   Year.append(a[i+1])
#   Award.append(a[i+2])
#   Nomination.append(a[i+3])
#   i+=4
i=0
while(i<(len(a)-4)):
  Film.append(re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[i])))
  Year.append(re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[i+1])))
  Award.append(re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[i+2])))
  Nomination.append(re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(arr[i+3])))
  i+=4

# %%
Film
# Out:
# ['Oppenheimer',
#  'Poor Things',
#  'The Zone of Interest',
#  'American Fiction',
#  'Anatomy of a Fall',
#  'Barbie',
#  'The Boy and the Heron',
#  'Godzilla Minus One',
#  'The Holdovers',
#  'The Last Repair Shop',
#  '20 Days in Mariupol',
#  'War Is Over! Inspired by the Music of John and Yoko',
#  'The Wonderful Story of Henry Sugar',
#  'Everything Everywhere All at Once',
#  'All Quiet on the Western Front',
#  'The Whale',
#  'Top Gun: Maverick',
#  'Black Panther: Wakanda Forever',
#  'Avatar: The Way of Water',
#  'Women Talking',
#  "Guillermo del Toro's Pinocchio",
#  ' Navalny',
#  'The Elephant Whisperers',
#  'An Irish Goodbye',
#  ' The Boy, the Mole, the Fox and the Horse',
#  ' RRR',
#  'CODA',
#  'Dune',
#  ' The Eyes of Tammy Faye',
#  'No Time to Die',
#  'The Windshield Wiper',
#  ' The Long Goodbye',
#  'The Queen of Basketball',
#  'Summer of Soul',
#  ' Drive My Car',
#  'Encanto',
#  ' West Side Story',
#  ' Belfast',
#  ' The Power of the Dog',
# ...

# %%
# AAAAAnother approch
# Film1=[]
# Year1=[]
# Award1 = [ ]
# Nomination1 = [ ]
# count = 0
# for i in soup.findAll('td'):
#   if count == 0:
#     Film1.append(i)
#     count += 1
#   elif count == 1:
#     Year1.append(i)
#     count += 1
#   elif count == 2:
#     Award1.append(i)
#     count += 1
#   else:
#     count = 0
#     Nomination1.append(i)

# %%
Film1=[]
Year1=[]
Award1 = [ ]
Nomination1 = [ ]
count = 0
for i in soup.findAll('td'):
  i=re.sub('^<td>.*">|</.*</td>$|<td>|</td>|\n',"",str(i))
  if count == 0:
    Film1.append(i)
    count += 1
  elif count == 1:
    Year1.append(i)
    count += 1
  elif count == 2:
    Award1.append(i)
    count += 1
  else:
    count = 0
    Nomination1.append(i)

# %%
Year1
# Out:
# ['2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '21',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019</a>',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
# ...

# %%
####WEB SCRAPPING & DATA CLEANING DONE#################

# %%
###DATASET CREATION###########

# %%
df=pd.DataFrame({'Film':Film, 'Year':Year, 'Award':Award, 'Nomination':Nomination})

# %%
df
# Out:
#                                                    Film  \
# 0                                           Oppenheimer
# 1                                           Poor Things
# 2                                  The Zone of Interest
# 3                                      American Fiction
# 4                                     Anatomy of a Fall
# ...                                                 ...
# 1370                      Yesterday, Today and Tomorrow
# 1371                         You Can't Take It with You
# 1372                                    Zorba the Greek
# 1373  <td class="navbox-abovebelow" colspan="2" styl...
# 1374  <td class="navbox-list-with-group navbox-list ...
#
#                                                    Year  \
# 0                                                  2023
# 1                                                  2023
# 2                                                  2023
# 3                                                  2023
# ...

# %%
len(Film)
# Out:
# 1375

# %%
len(Year)
# Out:
# 1375

# %%
len(Award)
# Out:
# 1375

# %%
len(Nomination)
# Out:
# 1375

# %%
# Film[# check after when you dont want]
Film[1000]
# Out:
# 'Quiet Please!'

# %%
Film[1100]
# Out:
# 'Lilies of the Field'

# %%
Film[1300]
# Out:
# "Thursday's Children"

# %%
Film[1320]
# Out:
# 'The True Story of the Civil War'

# %%
Film[1350]
# Out:
# "Who's Who in Animal Land"

# %%
Film[1370]
# Out:
# 'Yesterday, Today and Tomorrow'

# %%
Film[1372]
# Out:
# 'Zorba the Greek'

# %%
Film[1374]
# Out:
# '<td class="navbox-list-with-group navbox-list navbox-even" style="width:100%;padding:0"><div style="padding:0 0.25em"><ul><li><a class="mw-selflink selflink">Winning films</a></li><li><a href="/wiki/List_of_movies_with_more_than_one_Academy_Award_nomination_in_the_same_category" title="List of movies with more than one Academy Award nomination in the same category">Multi-noms in same category</a></li><li><a href="/wiki/List_of_films_with_two_or_more_Academy_Awards_in_an_acting_category" title="List of films with two or more Academy Awards in an acting category">Two acting awards for same film</a></li><li><a href="/wiki/List_of_Academy_Award%E2%80%93winning_foreign-language_films" title="List of Academy Award–winning foreign-language films">Foreign-language wins</a></li><li><a href="/wiki/List_of_foreign-language_films_nominated_for_Academy_Awards" title="List of foreign-language films nominated for Academy Awards">Foreign-language noms in other categories</a></li><li><a href="/wiki/
# ...

# %%
Film[1373]
# Out:
# '<td class="navbox-abovebelow" colspan="2" style="background:#EEDD82;"><div><ul><li><b><a href="/wiki/Academy_of_Motion_Picture_Arts_and_Sciences" title="Academy of Motion Picture Arts and Sciences">Academy of Motion Picture Arts and Sciences (AMPAS)</a></b></li></ul><ul><li><a href="/wiki/List_of_Academy_Award_records" title="List of Academy Award records">Records</a></li><li><a href="/wiki/List_of_films_with_the_most_Academy_Awards_per_ceremony" title="List of films with the most Academy Awards per ceremony">Most awards per ceremony</a></li></ul>'

# %%
# so need till 1372 elements, the elements from 1374 are not needed
# so rewrite DF creation
df=pd.DataFrame({'Film':Film[:1373], 'Year':Year[:1373], 'Award':Award[:1373], 'Nomination':Nomination[:1373]})

# %%
df
# Out:
#                                Film  Year Award Nomination
# 0                       Oppenheimer  2023     7         13
# 1                       Poor Things  2023     4         11
# 2              The Zone of Interest  2023     2          5
# 3                  American Fiction  2023     1          5
# 4                 Anatomy of a Fall  2023     1          5
# ...                             ...   ...   ...        ...
# 1368        The Yankee Doodle Mouse  1943     1          1
# 1369                   The Yearling  1946     2          7
# 1370  Yesterday, Today and Tomorrow  1964     1          1
# 1371     You Can't Take It with You  1938     2          7
# 1372                Zorba the Greek  1964     3          7
#
# [1373 rows x 4 columns]

# %%
# cross check with webpage
#Good Job...........................................................................................

# %%
############################Dataset Ready##############################

# %%
##################now do as usual#################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1373 entries, 0 to 1372
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Film        1373 non-null   object
#  1   Year        1373 non-null   object
#  2   Award       1373 non-null   object
#  3   Nomination  1373 non-null   object
# dtypes: object(4)
# memory usage: 43.0+ KB

# %%
# ## see dtype should be int but object
# # need to change, is there any discrebency
# #check the webpage
# col3: some values are :	0 (1)
# col4: some values are: 6[10]
